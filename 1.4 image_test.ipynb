# %%
from skimage.transform import rescale

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('floor_plan_image/c879c493-a9f1-493e-b291-d6e14c60b3dd.png')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print(img.shape)

img_resize = resize(img, (300,300,3))
# Out:
# (1445, 3000, 3)

# %%
imgplot = plt.imshow(img)
plt.show()

# %%
img_resize.shape
# Out:
# (300, 300)
